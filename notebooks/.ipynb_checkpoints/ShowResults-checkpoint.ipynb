# %%
import numpy as np


def mean_reciprocal_rank(rs):
    rs = (np.asarray(r).nonzero()[0] for r in rs)
    return np.mean([1. / (r[0] + 1) if r.size else 0. for r in rs])


def r_precision(r):
    r = np.asarray(r) != 0
    z = r.nonzero()[0]
    if not z.size:
        return 0.
    return np.mean(r[:z[-1] + 1])


def precision_at_k(r, k):
    assert k >= 1
    r = np.asarray(r)[:k] != 0
    if r.size != k:
        raise ValueError('Relevance score length < k')
    return np.mean(r)


def average_precision(r,max_k):
    r = np.asarray(r) != 0
    out = [precision_at_k(r, k + 1) for k in range(max_k) if r[k]]
    if not out:
        return 0.
    return np.mean(out)


def mean_average_precision_at_k(rs,max_k):
    return np.mean([average_precision(r,max_k) for r in rs])

# def dcg_at_k(r, k, method=0):
#     r = np.asfarray(r)[:k]
#     if r.size:
#         if method == 0:
#             return r[0] + np.sum(r[1:] / np.log2(np.arange(2, r.size + 1)))
#         elif method == 1:
#             return np.sum(r / np.log2(np.arange(2, r.size + 2)))
#         else:
#             raise ValueError('method must be 0 or 1.')
#     return 0.


# def ndcg_at_k(r, k, method=0):
#     dcg_max = dcg_at_k(sorted(r, reverse=True), k, method)
#     if not dcg_max:
#         return 0.
#     return dcg_at_k(r, k, method) / dcg_max

#KAGGLE
def dcg_at_k(r, k):
    r = np.asfarray(r)[:k]
    if r.size:
        return np.sum(np.subtract(np.power(2, r), 1) / np.log2(np.arange(2, r.size + 2)))
    return 0.


def ndcg_at_k(r, k):
    idcg = dcg_at_k(sorted(r, reverse=True), k)
    if not idcg:
        return 0.
    return dcg_at_k(r, k) / idcg

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../csv/statistics.csv')
df = df.dropna()
df.head(11)
# Out:
#                          query  \
# 0          download free music
# 1         detect text language
# 2          download web videos
# 3    check valid email address
# 4                     send sms
# 5               health tracker
# 6         quick sort algorithm
# 7       credit card validation
# 8   third party authentication
# 9    calculate word similarity
# 10       mobilie app framework
#
#                                     npmjs.com_optimal  \
# 0   csv/statistics/npmjs.com_optimal_download free...
# 1   csv/statistics/npmjs.com_optimal_detect text l...
# 2   csv/statistics/npmjs.com_optimal_download web ...
# 3   csv/statistics/npmjs.com_optimal_check valid e...
# 4       csv/statistics/npmjs.com_optimal_send sms.csv
# 5   csv/statistics/npmjs.com_optimal_health tracke...
# 6   csv/statistics/npmjs.com_optimal_quick sort al...
# 7   csv/statistics/npmjs.com_optimal_credit card v...
# 8   csv/statistics/npmjs.com_optimal_third party a...
# 9   csv/statistics/npmjs.com_optimal_calculate wor...
# 10  csv/statistics/npmjs.com_optimal_mobilie app f...
#
#                                         npmsearch.com  \
# 0   csv/statistics/npmsearch.com_download free mus...
# 1   csv/statistics/npmsearch.com_detect text langu...
# 2   csv/statistics/npmsearch.com_download web vide...
# 3   csv/statistics/npmsearch.com_check valid email...
# 4           csv/statistics/npmsearch.com_send sms.csv
# 5     csv/statistics/npmsearch.com_health tracker.csv
# 6   csv/statistics/npmsearch.com_quick sort algori...
# 7   csv/statistics/npmsearch.com_credit card valid...
# 8   csv/statistics/npmsearch.com_third party authe...
# 9   csv/statistics/npmsearch.com_calculate word si...
# 10  csv/statistics/npmsearch.com_mobilie app frame...
#
#                                                   M1  \
# 0          csv/statistics/M1_download free music.csv
# 1         csv/statistics/M1_detect text language.csv
# 2          csv/statistics/M1_download web videos.csv
# 3    csv/statistics/M1_check valid email address.csv
# 4                     csv/statistics/M1_send sms.csv
# 5               csv/statistics/M1_health tracker.csv
# 6         csv/statistics/M1_quick sort algorithm.csv
# 7       csv/statistics/M1_credit card validation.csv
# 8   csv/statistics/M1_third party authentication.csv
# 9    csv/statistics/M1_calculate word similarity.csv
# 10       csv/statistics/M1_mobilie app framework.csv
#
#                                                   M2  \
# 0          csv/statistics/M2_download free music.csv
# 1         csv/statistics/M2_detect text language.csv
# 2          csv/statistics/M2_download web videos.csv
# 3    csv/statistics/M2_check valid email address.csv
# 4                     csv/statistics/M2_send sms.csv
# 5               csv/statistics/M2_health tracker.csv
# 6         csv/statistics/M2_quick sort algorithm.csv
# 7       csv/statistics/M2_credit card validation.csv
# 8   csv/statistics/M2_third party authentication.csv
# 9    csv/statistics/M2_calculate word similarity.csv
# 10       csv/statistics/M2_mobilie app framework.csv
#
#                                                   M3  \
# 0          csv/statistics/M3_download free music.csv
# 1         csv/statistics/M3_detect text language.csv
# 2          csv/statistics/M3_download web videos.csv
# 3    csv/statistics/M3_check valid email address.csv
# 4                     csv/statistics/M3_send sms.csv
# 5               csv/statistics/M3_health tracker.csv
# 6         csv/statistics/M3_quick sort algorithm.csv
# 7       csv/statistics/M3_credit card validation.csv
# 8   csv/statistics/M3_third party authentication.csv
# 9    csv/statistics/M3_calculate word similarity.csv
# 10       csv/statistics/M3_mobilie app framework.csv
#
#                                                   M4  \
# 0          csv/statistics/M4_download free music.csv
# 1         csv/statistics/M4_detect text language.csv
# 2          csv/statistics/M4_download web videos.csv
# 3    csv/statistics/M4_check valid email address.csv
# 4                     csv/statistics/M4_send sms.csv
# 5               csv/statistics/M4_health tracker.csv
# 6         csv/statistics/M4_quick sort algorithm.csv
# 7       csv/statistics/M4_credit card validation.csv
# 8   csv/statistics/M4_third party authentication.csv
# 9    csv/statistics/M4_calculate word similarity.csv
# 10       csv/statistics/M4_mobilie app framework.csv
#
#                                             BordaFuse  \
# 0    csv/statistics/BordaFuse_download free music.csv
# 1   csv/statistics/BordaFuse_detect text language.csv
# 2    csv/statistics/BordaFuse_download web videos.csv
# 3   csv/statistics/BordaFuse_check valid email add...
# 4               csv/statistics/BordaFuse_send sms.csv
# 5         csv/statistics/BordaFuse_health tracker.csv
# 6   csv/statistics/BordaFuse_quick sort algorithm.csv
# 7   csv/statistics/BordaFuse_credit card validatio...
# 8   csv/statistics/BordaFuse_third party authentic...
# 9   csv/statistics/BordaFuse_calculate word simila...
# 10  csv/statistics/BordaFuse_mobilie app framework...
#
#                                             Cordorcet  \
# 0    csv/statistics/Cordorcet_download free music.csv
# 1   csv/statistics/Cordorcet_detect text language.csv
# 2    csv/statistics/Cordorcet_download web videos.csv
# 3   csv/statistics/Cordorcet_check valid email add...
# 4               csv/statistics/Cordorcet_send sms.csv
# 5         csv/statistics/Cordorcet_health tracker.csv
# 6   csv/statistics/Cordorcet_quick sort algorithm.csv
# 7   csv/statistics/Cordorcet_credit card validatio...
# 8   csv/statistics/Cordorcet_third party authentic...
# 9   csv/statistics/Cordorcet_calculate word simila...
# 10  csv/statistics/Cordorcet_mobilie app framework...
#
#                                      BoostedBordaFuse  \
# 0   csv/statistics/BoostedBordaFuse_download free ...
# 1   csv/statistics/BoostedBordaFuse_detect text la...
# 2   csv/statistics/BoostedBordaFuse_download web v...
# 3   csv/statistics/BoostedBordaFuse_check valid em...
# 4        csv/statistics/BoostedBordaFuse_send sms.csv
# 5   csv/statistics/BoostedBordaFuse_health tracker...
# 6   csv/statistics/BoostedBordaFuse_quick sort alg...
# 7   csv/statistics/BoostedBordaFuse_credit card va...
# 8   csv/statistics/BoostedBordaFuse_third party au...
# 9   csv/statistics/BoostedBordaFuse_calculate word...
# 10  csv/statistics/BoostedBordaFuse_mobilie app fr...
#
#                                     WeightedBordaFuse  \
# 0   csv/statistics/WeightedBordaFuse_download free...
# 1   csv/statistics/WeightedBordaFuse_detect text l...
# 2   csv/statistics/WeightedBordaFuse_download web ...
# 3   csv/statistics/WeightedBordaFuse_check valid e...
# 4       csv/statistics/WeightedBordaFuse_send sms.csv
# 5   csv/statistics/WeightedBordaFuse_health tracke...
# 6   csv/statistics/WeightedBordaFuse_quick sort al...
# 7   csv/statistics/WeightedBordaFuse_credit card v...
# 8   csv/statistics/WeightedBordaFuse_third party a...
# 9   csv/statistics/WeightedBordaFuse_calculate wor...
# 10  csv/statistics/WeightedBordaFuse_mobilie app f...
#
#                           Filter_google.com_hyp_match
# 0   csv/statistics/Filter_google.com_hyp_match_dow...
# 1   csv/statistics/Filter_google.com_hyp_match_det...
# 2   csv/statistics/Filter_google.com_hyp_match_dow...
# 3   csv/statistics/Filter_google.com_hyp_match_che...
# 4   csv/statistics/Filter_google.com_hyp_match_sen...
# 5   csv/statistics/Filter_google.com_hyp_match_hea...
# 6   csv/statistics/Filter_google.com_hyp_match_qui...
# 7   csv/statistics/Filter_google.com_hyp_match_cre...
# 8   csv/statistics/Filter_google.com_hyp_match_thi...
# 9   csv/statistics/Filter_google.com_hyp_match_cal...
# 10  csv/statistics/Filter_google.com_hyp_match_mob...

# %%
searchers = list(df).copy()
del searchers[0]

for query in range(df['query'].size):
    for searcher in range(len(searchers)):
        mt = pd.read_csv('../'+df.iloc[query][searcher+1])
        df.iloc[query][searcher+1] = mt

# %%
print(searchers)
print(df['query'].tolist())
# Out:
# ['npmjs.com_optimal', 'npmsearch.com', 'M1', 'M2', 'M3', 'M4', 'BordaFuse', 'Cordorcet', 'BoostedBordaFuse', 'WeightedBordaFuse', 'Filter_google.com_hyp_match']
# ['download free music', 'detect text language', 'download web videos', 'check valid email address', 'send sms', 'health tracker', 'quick sort algorithm', 'credit card validation', 'third party authentication', 'calculate word similarity', 'mobilie app framework', 'convert typewritten image to text', 'user authentication', 'filter adult content images', 'lightweight 3D graphic library', 'convert text to speech', 'extract barcode from image', 'mathematical functions', 'sentiment analysis', 'rank aggregation algorithms', 'convert data formats', 'translate english to spanish', 'captcha authentication', 'DOM manipulation utils', 'scraper']

# %%
#df = pd.DataFrame([list(s1), list(s2)],  columns =  ["A", "B", "C"])

max_k = 21
resultall = []
result_precision = []
result_hits = []
result_recall = []
result_fmeasure = []
result_ndcg_k = []
result_mean_average_precision = []

#Searchers Used
#print(searchers)
arr_searchers = pd.Series(['npmjs.com_optimal', 'npmsearch.com', 'M1', 'M2','M3', 'M4', 'BordaFuse', 'Cordorcet', 'WeightedBordaFuse', 'Filter_google.com_hyp_match'])
#Queries Used
#print(df['query'].tolist())
arr_queries = pd.Series(['download free music', 'detect text language', 'download web videos', 'check valid email address', 
                         'send sms', 'health tracker', 'quick sort algorithm', 'credit card validation', 
                         'third party authentication', 'calculate word similarity', 'mobilie app framework', 
                         'convert typewritten image to text', 'user authentication', 'filter adult content images', 
                         'lightweight 3D graphic library', 'convert text to speech', 'extract barcode from image', 
                         'mathematical functions', 'sentiment analysis', 'rank aggregation algorithms', 
                         'convert data formats', 'translate english to spanish', 'captcha authentication', 
                         'DOM manipulation utils', 'scraper'])


#Calculo de precision, recall y hits
for k in range(1,max_k):
    #print(k)
    searchersrow = []
    row_precision = []
    row_hits = []
    row_recall = []
    row_fmeasure = []
    row_ndcg_k = []
    row_mean_average_precision = []
       
    for searcher in range(arr_searchers.size):
        #print(searchers[searcher])
        sum_hits = 0
        sum_precision = 0
        sum_recall = 0
        sum_fmeasure = 0
        sum_ndcg_k = 0
        arr_rs = []    
    
        for query in range(arr_queries.size):
            #print(arr_queries[query])
            idxq = df.index[df['query'] == arr_queries[query]].tolist()
            idxs = searchers.index(arr_searchers[searcher])
            sxq = df.iloc[idxq[0]][idxs+1]
            sxq = sxq.set_index('k')
            sum_hits += sxq.loc[k]['#hits']
            sum_precision += sxq.loc[k]['precision']
            sum_recall += sxq.loc[k]['recall']
            sum_fmeasure += sxq.loc[k]['fmeasure']
            sum_ndcg_k += ndcg_at_k(sxq['hit'],k)
            arr_rs.append(sxq['hit']);
            
        prom_hits = sum_hits/arr_queries.size
        prom_precision = sum_precision/arr_queries.size
        prom_recall = sum_recall/arr_queries.size
        prom_fmeasure = sum_fmeasure/arr_queries.size
        prom_ndcg_k = sum_ndcg_k/arr_queries.size
        mean_average_precision = mean_average_precision_at_k(arr_rs,k)
        #print(prom_hits)
        #print(prom_precision)
        #print(prom_recall)
        #print(prom_fmeasure)
        searcherprom = pd.DataFrame([[prom_hits,prom_precision,prom_recall,prom_fmeasure,prom_ndcg_k,mean_average_precision]],  columns =  ["hits", "precision", "recall", "fmeasure","ncdg","map"])
        searchersrow.append(searcherprom)
        row_precision.append(prom_precision)
        row_hits.append(prom_hits)
        row_recall.append(prom_recall)
        row_fmeasure.append(prom_fmeasure)
        row_ndcg_k.append(prom_ndcg_k)
        row_mean_average_precision.append(mean_average_precision)
    #print(searchersrow)
    resultall.append([k]+searchersrow)
    result_precision.append([k]+row_precision)
    result_hits.append([k]+row_hits)
    result_recall.append([k]+row_recall)
    result_fmeasure.append([k]+row_fmeasure)
    result_ndcg_k.append([k]+row_ndcg_k)
    result_mean_average_precision.append([k]+row_mean_average_precision)

columnsk = ['k'] + arr_searchers
dataframek = pd.DataFrame(resultall, columns =  ['k'] + arr_searchers.tolist())
dataframek = dataframek.set_index('k')
dataframek.head(3)

dataframe_hits = pd.DataFrame(result_hits, columns =  ['k'] + arr_searchers.tolist())
dataframe_recall = pd.DataFrame(result_recall, columns =  ['k'] + arr_searchers.tolist())
dataframe_fmeasure = pd.DataFrame(result_fmeasure, columns =  ['k'] + arr_searchers.tolist())
dataframe_precision = pd.DataFrame(result_precision, columns =  ['k'] + arr_searchers.tolist())
dataframe_ndcg_k = pd.DataFrame(result_ndcg_k, columns =  ['k'] + arr_searchers.tolist())
dataframe_average_precision = pd.DataFrame(result_mean_average_precision, columns =  ['k'] + arr_searchers.tolist())

dataframe_ndcg_k.head(20)
# Out:
#      k  npmjs.com_optimal  npmsearch.com        M1        M2        M3  \
# 0    1           0.600000       0.320000  0.760000  0.760000  0.720000
# 1    2           0.600000       0.345237  0.760000  0.760000  0.704526
# 2    3           0.606508       0.335852  0.728966  0.728966  0.695894
# 3    4           0.623990       0.330704  0.727656  0.720931  0.700145
# 4    5           0.635744       0.322115  0.735683  0.735088  0.707557
# 5    6           0.634752       0.328919  0.733168  0.736949  0.711976
# 6    7           0.631039       0.326749  0.735912  0.732016  0.713202
# 7    8           0.631293       0.331416  0.735699  0.735306  0.718173
# 8    9           0.636843       0.335224  0.746420  0.743225  0.727462
# 9   10           0.639316       0.333316  0.748698  0.748251  0.731089
# 10  11           0.643379       0.326327  0.753716  0.753295  0.739569
# 11  12           0.642646       0.324531  0.753664  0.753265  0.740387
# 12  13           0.642004       0.325272  0.760362  0.759983  0.745885
# 13  14           0.643001       0.328167  0.763631  0.765070  0.751718
# 14  15           0.645656       0.332474  0.768670  0.773591  0.762378
# 15  16           0.646364       0.338471  0.775092  0.778183  0.768995
# 16  17           0.650100       0.342255  0.784824  0.789134  0.780222
# 17  18           0.653609       0.347040  0.792893  0.798682  0.788391
# 18  19           0.658103       0.353470  0.806553  0.809425  0.802109
# 19  20           0.660776       0.361802  0.819208  0.819130  0.811706
#
#           M4  BordaFuse  Cordorcet  WeightedBordaFuse  \
# 0   0.520000   0.680000   0.800000           0.680000
# 1   0.535474   0.726422   0.753578           0.726422
# 2   0.551843   0.762458   0.745699           0.750195
# 3   0.551480   0.766973   0.712900           0.765273
# 4   0.567517   0.773396   0.724378           0.771696
# 5   0.578277   0.752111   0.723076           0.750411
# 6   0.581659   0.757373   0.731804           0.755673
# 7   0.587338   0.764230   0.739433           0.762530
# 8   0.599062   0.762551   0.737848           0.760851
# 9   0.608313   0.760638   0.743648           0.758938
# 10  0.613138   0.769029   0.747193           0.767329
# 11  0.618639   0.765525   0.750370           0.763825
# 12  0.631309   0.771163   0.753537           0.769463
# 13  0.641561   0.773123   0.759353           0.769598
# 14  0.662186   0.779308   0.765015           0.777568
# 15  0.673976   0.779161   0.773599           0.777422
# 16  0.686461   0.788436   0.784918           0.786699
# 17  0.704695   0.794809   0.794422           0.793073
# 18  0.718583   0.807147   0.811107           0.805411
# 19  0.734618   0.818439   0.822196           0.816703
#
#     Filter_google.com_hyp_match
# 0                      0.640000
# 1                      0.640000
# 2                      0.662402
# 3                      0.671845
# 4                      0.697226
# 5                      0.711311
# 6                      0.711595
# 7                      0.716726
# 8                      0.714305
# 9                      0.718450
# 10                     0.722288
# 11                     0.727360
# 12                     0.732552
# 13                     0.732776
# 14                     0.735326
# 15                     0.735505
# 16                     0.739331
# 17                     0.742826
# 18                     0.742826
# 19                     0.744966

# %%
import matplotlib.pyplot as pl
import seaborn as sns

sns.set_style("whitegrid")


def plplotk(pl,searcher,dataf):
        pl.plot(dataf['k'].tolist(), dataf[searcher].tolist(), label=searcher)

for searcher in range(arr_searchers.size):
    plplotk(pl,arr_searchers[searcher],dataframe_hits)
    
pl.xlabel('k')
pl.ylabel('hits')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-hit curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()


for searcher in range(arr_searchers.size):
    plplotk(pl,arr_searchers[searcher],dataframe_precision)
    
pl.xlabel('k')
pl.ylabel('precision')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-precision curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()


for searcher in range(arr_searchers.size):
    plplotk(pl,arr_searchers[searcher],dataframe_recall)
    
pl.xlabel('k')
pl.ylabel('recall')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-recall curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()

for searcher in range(arr_searchers.size):
    plplotk(pl,arr_searchers[searcher],dataframe_fmeasure)
    
pl.xlabel('k')
pl.ylabel('f-measure')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-f-measure curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()

for searcher in range(arr_searchers.size):
    plplotk(pl,arr_searchers[searcher],dataframe_ndcg_k)
    
pl.xlabel('k')
pl.ylabel('ndcg')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('ndcg curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()

for searcher in range(arr_searchers.size):
    plplotk(pl,arr_searchers[searcher],dataframe_average_precision)
    
pl.xlabel('k')
pl.ylabel('map')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('map curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()

# %%
dataframe_average_precision.head(20)
# Out:
#      k  npmjs.com_optimal  npmsearch.com        M1        M2        M3  \
# 0    1           0.600000       0.320000  0.760000  0.760000  0.720000
# 1    2           0.660000       0.360000  0.800000  0.800000  0.780000
# 2    3           0.640000       0.353333  0.800000  0.800000  0.783333
# 3    4           0.634444       0.350000  0.791111  0.791111  0.772222
# 4    5           0.632500       0.348833  0.770889  0.768889  0.754167
# 5    6           0.628267       0.340622  0.769722  0.768400  0.747167
# 6    7           0.626860       0.339698  0.763213  0.763295  0.742190
# 7    8           0.623522       0.337041  0.760562  0.759658  0.738213
# 8    9           0.621592       0.336183  0.758277  0.758110  0.737264
# 9   10           0.620034       0.336106  0.751662  0.750391  0.731323
# 10  11           0.619288       0.335743  0.745198  0.743894  0.725702
# 11  12           0.618894       0.335098  0.743722  0.742409  0.725572
# 12  13           0.618281       0.332936  0.738899  0.737639  0.721525
# 13  14           0.617722       0.332811  0.737638  0.736673  0.721364
# 14  15           0.617041       0.331524  0.734746  0.733967  0.719381
# 15  16           0.616859       0.329765  0.734178  0.733731  0.720195
# 16  17           0.616424       0.328292  0.732554  0.732282  0.719391
# 17  18           0.615993       0.327578  0.732266  0.732133  0.719528
# 18  19           0.615888       0.327135  0.730779  0.730881  0.718973
# 19  20           0.615793       0.325526  0.728913  0.729466  0.717957
#
#           M4  BordaFuse  Cordorcet  WeightedBordaFuse  \
# 0   0.520000   0.680000   0.800000           0.680000
# 1   0.620000   0.760000   0.820000           0.760000
# 2   0.626667   0.800000   0.830000           0.786667
# 3   0.623333   0.793333   0.807778           0.790000
# 4   0.625556   0.791389   0.782444           0.788056
# 5   0.622978   0.791256   0.771456           0.787922
# 6   0.626589   0.783440   0.761235           0.780106
# 7   0.628332   0.778034   0.753656           0.776367
# 8   0.615903   0.776032   0.752212           0.774366
# 9   0.610103   0.769898   0.743767           0.768231
# 10  0.609613   0.761684   0.737485           0.760018
# 11  0.608940   0.759227   0.735488           0.757561
# 12  0.607626   0.754273   0.731819           0.752606
# 13  0.606513   0.752979   0.730552           0.751312
# 14  0.604689   0.749282   0.728829           0.747425
# 15  0.603184   0.748005   0.728719           0.746161
# 16  0.602822   0.745573   0.727787           0.743729
# 17  0.603384   0.744967   0.728127           0.743133
# 18  0.603860   0.742789   0.727661           0.740965
# 19  0.604863   0.740317   0.726689           0.738502
#
#     Filter_google.com_hyp_match
# 0                      0.640000
# 1                      0.720000
# 2                      0.710000
# 3                      0.696667
# 4                      0.701278
# 5                      0.697856
# 6                      0.698176
# 7                      0.697624
# 8                      0.698347
# 9                      0.693094
# 10                     0.690664
# 11                     0.689736
# 12                     0.686199
# 13                     0.685993
# 14                     0.684404
# 15                     0.684303
# 16                     0.683172
# 17                     0.682820
# 18                     0.682820
# 19                     0.681902

# %%
dataframe_ndcg_k.head(20)
# Out:
#      k  npmjs.com_optimal  npmsearch.com        M1        M2        M3  \
# 0    1           0.600000       0.320000  0.760000  0.760000  0.720000
# 1    2           0.600000       0.345237  0.760000  0.760000  0.704526
# 2    3           0.606508       0.335852  0.728966  0.728966  0.695894
# 3    4           0.623990       0.330704  0.727656  0.720931  0.700145
# 4    5           0.635744       0.322115  0.735683  0.735088  0.707557
# 5    6           0.634752       0.328919  0.733168  0.736949  0.711976
# 6    7           0.631039       0.326749  0.735912  0.732016  0.713202
# 7    8           0.631293       0.331416  0.735699  0.735306  0.718173
# 8    9           0.636843       0.335224  0.746420  0.743225  0.727462
# 9   10           0.639316       0.333316  0.748698  0.748251  0.731089
# 10  11           0.643379       0.326327  0.753716  0.753295  0.739569
# 11  12           0.642646       0.324531  0.753664  0.753265  0.740387
# 12  13           0.642004       0.325272  0.760362  0.759983  0.745885
# 13  14           0.643001       0.328167  0.763631  0.765070  0.751718
# 14  15           0.645656       0.332474  0.768670  0.773591  0.762378
# 15  16           0.646364       0.338471  0.775092  0.778183  0.768995
# 16  17           0.650100       0.342255  0.784824  0.789134  0.780222
# 17  18           0.653609       0.347040  0.792893  0.798682  0.788391
# 18  19           0.658103       0.353470  0.806553  0.809425  0.802109
# 19  20           0.660776       0.361802  0.819208  0.819130  0.811706
#
#           M4  BordaFuse  Cordorcet  WeightedBordaFuse  \
# 0   0.520000   0.680000   0.800000           0.680000
# 1   0.535474   0.726422   0.753578           0.726422
# 2   0.551843   0.762458   0.745699           0.750195
# 3   0.551480   0.766973   0.712900           0.765273
# 4   0.567517   0.773396   0.724378           0.771696
# 5   0.578277   0.752111   0.723076           0.750411
# 6   0.581659   0.757373   0.731804           0.755673
# 7   0.587338   0.764230   0.739433           0.762530
# 8   0.599062   0.762551   0.737848           0.760851
# 9   0.608313   0.760638   0.743648           0.758938
# 10  0.613138   0.769029   0.747193           0.767329
# 11  0.618639   0.765525   0.750370           0.763825
# 12  0.631309   0.771163   0.753537           0.769463
# 13  0.641561   0.773123   0.759353           0.769598
# 14  0.662186   0.779308   0.765015           0.777568
# 15  0.673976   0.779161   0.773599           0.777422
# 16  0.686461   0.788436   0.784918           0.786699
# 17  0.704695   0.794809   0.794422           0.793073
# 18  0.718583   0.807147   0.811107           0.805411
# 19  0.734618   0.818439   0.822196           0.816703
#
#     Filter_google.com_hyp_match
# 0                      0.640000
# 1                      0.640000
# 2                      0.662402
# 3                      0.671845
# 4                      0.697226
# 5                      0.711311
# 6                      0.711595
# 7                      0.716726
# 8                      0.714305
# 9                      0.718450
# 10                     0.722288
# 11                     0.727360
# 12                     0.732552
# 13                     0.732776
# 14                     0.735326
# 15                     0.735505
# 16                     0.739331
# 17                     0.742826
# 18                     0.742826
# 19                     0.744966

# %%
tips = dataframe_ndcg_k[['npmjs.com_optimal', 'npmsearch.com',  'Filter_google.com_hyp_match', 'M1', 'M2','M3', 'M4', 'BordaFuse', 'Cordorcet', 'WeightedBordaFuse']]
sns.boxplot(data=tips, orient="h")
pl.show()

# %%
tips = dataframe_ndcg_k[['npmjs.com_optimal', 'npmsearch.com', 'Filter_google.com_hyp_match']]
tips = tips.rename(index=str, columns={'npmjs.com_optimal':'NPM (Repository-Provided)', 'npmsearch.com':'npmsearch.com(User-Created)','Filter_google.com_hyp_match':'NTE(General Purpose)'})
sns.boxplot(data=tips, orient="h")
pl.show()

# %%
tips = dataframe_average_precision[['npmjs.com_optimal', 'npmsearch.com', 'M1', 'M2','M3', 'M4', 'BordaFuse', 'Cordorcet', 'WeightedBordaFuse', 'Filter_google.com_hyp_match']]
sns.boxplot(data=tips, orient="h")
pl.show()

# %%
tips = dataframe_ndcg_k.iloc[[9]][['npmjs.com_optimal', 'Filter_google.com_hyp_match', 'npmsearch.com', 'M1', 'M2','M3', 'M4', 'BordaFuse', 'Cordorcet', 'WeightedBordaFuse']]

#deep, muted, pastel, bright, dark, and colorblind.
#current = sns.color_palette("deep")
sns.barplot(data=tips, orient="h")
pl.show()

tips = dataframe_average_precision.iloc[[9]][['npmjs.com_optimal', 'Filter_google.com_hyp_match', 'npmsearch.com', 'M1', 'M2','M3', 'M4', 'BordaFuse', 'Cordorcet', 'WeightedBordaFuse']]

#deep, muted, pastel, bright, dark, and colorblind.
#current = sns.color_palette("deep")
sns.barplot(data=tips, orient="h")
pl.show()
