# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../csv/statistics.csv')
df = df.dropna()
df
# Out:
#                          query  \
# 0          download free music
# 1          download web videos
# 2    check valid email address
# 3                     send sms
# 4   extract barcode from image
# 5        convert audio to text
# 6         quick sort algorithm
# 7          user authentication
# 8  filter adult content images
# 9         convert data formats
#
#                                               lucene  \
# 0      csv/statistics/lucene_download free music.csv
# 1      csv/statistics/lucene_download web videos.csv
# 2  csv/statistics/lucene_check valid email addres...
# 3                 csv/statistics/lucene_send sms.csv
# 4  csv/statistics/lucene_extract barcode from ima...
# 5    csv/statistics/lucene_convert audio to text.csv
# 6     csv/statistics/lucene_quick sort algorithm.csv
# 7      csv/statistics/lucene_user authentication.csv
# 8  csv/statistics/lucene_filter adult content ima...
# 9     csv/statistics/lucene_convert data formats.csv
#
#                                bing.com_stanford_CRF  \
# 0  csv/statistics/bing.com_stanford_CRF_download ...
# 1  csv/statistics/bing.com_stanford_CRF_download ...
# 2  csv/statistics/bing.com_stanford_CRF_check val...
# 3  csv/statistics/bing.com_stanford_CRF_send sms.csv
# 4  csv/statistics/bing.com_stanford_CRF_extract b...
# 5  csv/statistics/bing.com_stanford_CRF_convert a...
# 6  csv/statistics/bing.com_stanford_CRF_quick sor...
# 7  csv/statistics/bing.com_stanford_CRF_user auth...
# 8  csv/statistics/bing.com_stanford_CRF_filter ad...
# 9  csv/statistics/bing.com_stanford_CRF_convert d...
#
#                              google.com_stanford_CRF  \
# 0  csv/statistics/google.com_stanford_CRF_downloa...
# 1  csv/statistics/google.com_stanford_CRF_downloa...
# 2  csv/statistics/google.com_stanford_CRF_check v...
# 3  csv/statistics/google.com_stanford_CRF_send sm...
# 4  csv/statistics/google.com_stanford_CRF_extract...
# 5  csv/statistics/google.com_stanford_CRF_convert...
# 6  csv/statistics/google.com_stanford_CRF_quick s...
# 7  csv/statistics/google.com_stanford_CRF_user au...
# 8  csv/statistics/google.com_stanford_CRF_filter ...
# 9  csv/statistics/google.com_stanford_CRF_convert...
#
#                                   bing.com_str_match  \
# 0  csv/statistics/bing.com_str_match_download fre...
# 1  csv/statistics/bing.com_str_match_download web...
# 2  csv/statistics/bing.com_str_match_check valid ...
# 3     csv/statistics/bing.com_str_match_send sms.csv
# 4  csv/statistics/bing.com_str_match_extract barc...
# 5  csv/statistics/bing.com_str_match_convert audi...
# 6  csv/statistics/bing.com_str_match_quick sort a...
# 7  csv/statistics/bing.com_str_match_user authent...
# 8  csv/statistics/bing.com_str_match_filter adult...
# 9  csv/statistics/bing.com_str_match_convert data...
#
#                                 google.com_str_match  \
# 0  csv/statistics/google.com_str_match_download f...
# 1  csv/statistics/google.com_str_match_download w...
# 2  csv/statistics/google.com_str_match_check vali...
# 3   csv/statistics/google.com_str_match_send sms.csv
# 4  csv/statistics/google.com_str_match_extract ba...
# 5  csv/statistics/google.com_str_match_convert au...
# 6  csv/statistics/google.com_str_match_quick sort...
# 7  csv/statistics/google.com_str_match_user authe...
# 8  csv/statistics/google.com_str_match_filter adu...
# 9  csv/statistics/google.com_str_match_convert da...
#
#                                   bing.com_hyp_match  \
# 0  csv/statistics/bing.com_hyp_match_download fre...
# 1  csv/statistics/bing.com_hyp_match_download web...
# 2  csv/statistics/bing.com_hyp_match_check valid ...
# 3     csv/statistics/bing.com_hyp_match_send sms.csv
# 4  csv/statistics/bing.com_hyp_match_extract barc...
# 5  csv/statistics/bing.com_hyp_match_convert audi...
# 6  csv/statistics/bing.com_hyp_match_quick sort a...
# 7  csv/statistics/bing.com_hyp_match_user authent...
# 8  csv/statistics/bing.com_hyp_match_filter adult...
# 9  csv/statistics/bing.com_hyp_match_convert data...
#
#                                 google.com_hyp_match  \
# 0  csv/statistics/google.com_hyp_match_download f...
# 1  csv/statistics/google.com_hyp_match_download w...
# 2  csv/statistics/google.com_hyp_match_check vali...
# 3   csv/statistics/google.com_hyp_match_send sms.csv
# 4  csv/statistics/google.com_hyp_match_extract ba...
# 5  csv/statistics/google.com_hyp_match_convert au...
# 6  csv/statistics/google.com_hyp_match_quick sort...
# 7  csv/statistics/google.com_hyp_match_user authe...
# 8  csv/statistics/google.com_hyp_match_filter adu...
# 9  csv/statistics/google.com_hyp_match_convert da...
#
#                                    npmjs.com_optimal  \
# 0  csv/statistics/npmjs.com_optimal_download free...
# 1  csv/statistics/npmjs.com_optimal_download web ...
# 2  csv/statistics/npmjs.com_optimal_check valid e...
# 3      csv/statistics/npmjs.com_optimal_send sms.csv
# 4  csv/statistics/npmjs.com_optimal_extract barco...
# 5  csv/statistics/npmjs.com_optimal_convert audio...
# 6  csv/statistics/npmjs.com_optimal_quick sort al...
# 7  csv/statistics/npmjs.com_optimal_user authenti...
# 8  csv/statistics/npmjs.com_optimal_filter adult ...
# 9  csv/statistics/npmjs.com_optimal_convert data ...
#
#                                        npmsearch.com  \
# 0  csv/statistics/npmsearch.com_download free mus...
# 1  csv/statistics/npmsearch.com_download web vide...
# 2  csv/statistics/npmsearch.com_check valid email...
# 3          csv/statistics/npmsearch.com_send sms.csv
# 4  csv/statistics/npmsearch.com_extract barcode f...
# 5  csv/statistics/npmsearch.com_convert audio to ...
# 6  csv/statistics/npmsearch.com_quick sort algori...
# 7  csv/statistics/npmsearch.com_user authenticati...
# 8  csv/statistics/npmsearch.com_filter adult cont...
# 9  csv/statistics/npmsearch.com_convert data form...
#
#                                                   M1  \
# 0          csv/statistics/M1_download free music.csv
# 1          csv/statistics/M1_download web videos.csv
# 2    csv/statistics/M1_check valid email address.csv
# 3                     csv/statistics/M1_send sms.csv
# 4   csv/statistics/M1_extract barcode from image.csv
# 5        csv/statistics/M1_convert audio to text.csv
# 6         csv/statistics/M1_quick sort algorithm.csv
# 7          csv/statistics/M1_user authentication.csv
# 8  csv/statistics/M1_filter adult content images.csv
# 9         csv/statistics/M1_convert data formats.csv
#
#                                                   M2  \
# 0          csv/statistics/M2_download free music.csv
# 1          csv/statistics/M2_download web videos.csv
# 2    csv/statistics/M2_check valid email address.csv
# 3                     csv/statistics/M2_send sms.csv
# 4   csv/statistics/M2_extract barcode from image.csv
# 5        csv/statistics/M2_convert audio to text.csv
# 6         csv/statistics/M2_quick sort algorithm.csv
# 7          csv/statistics/M2_user authentication.csv
# 8  csv/statistics/M2_filter adult content images.csv
# 9         csv/statistics/M2_convert data formats.csv
#
#                                                   M3  \
# 0          csv/statistics/M3_download free music.csv
# 1          csv/statistics/M3_download web videos.csv
# 2    csv/statistics/M3_check valid email address.csv
# 3                     csv/statistics/M3_send sms.csv
# 4   csv/statistics/M3_extract barcode from image.csv
# 5        csv/statistics/M3_convert audio to text.csv
# 6         csv/statistics/M3_quick sort algorithm.csv
# 7          csv/statistics/M3_user authentication.csv
# 8  csv/statistics/M3_filter adult content images.csv
# 9         csv/statistics/M3_convert data formats.csv
#
#                                                   M4  \
# 0          csv/statistics/M4_download free music.csv
# 1          csv/statistics/M4_download web videos.csv
# 2    csv/statistics/M4_check valid email address.csv
# 3                     csv/statistics/M4_send sms.csv
# 4   csv/statistics/M4_extract barcode from image.csv
# 5        csv/statistics/M4_convert audio to text.csv
# 6         csv/statistics/M4_quick sort algorithm.csv
# 7          csv/statistics/M4_user authentication.csv
# 8  csv/statistics/M4_filter adult content images.csv
# 9         csv/statistics/M4_convert data formats.csv
#
#                                            BordaFuse  \
# 0   csv/statistics/BordaFuse_download free music.csv
# 1   csv/statistics/BordaFuse_download web videos.csv
# 2  csv/statistics/BordaFuse_check valid email add...
# 3              csv/statistics/BordaFuse_send sms.csv
# 4  csv/statistics/BordaFuse_extract barcode from ...
# 5  csv/statistics/BordaFuse_convert audio to text...
# 6  csv/statistics/BordaFuse_quick sort algorithm.csv
# 7   csv/statistics/BordaFuse_user authentication.csv
# 8  csv/statistics/BordaFuse_filter adult content ...
# 9  csv/statistics/BordaFuse_convert data formats.csv
#
#                                            Cordorcet  \
# 0   csv/statistics/Cordorcet_download free music.csv
# 1   csv/statistics/Cordorcet_download web videos.csv
# 2  csv/statistics/Cordorcet_check valid email add...
# 3              csv/statistics/Cordorcet_send sms.csv
# 4  csv/statistics/Cordorcet_extract barcode from ...
# 5  csv/statistics/Cordorcet_convert audio to text...
# 6  csv/statistics/Cordorcet_quick sort algorithm.csv
# 7   csv/statistics/Cordorcet_user authentication.csv
# 8  csv/statistics/Cordorcet_filter adult content ...
# 9  csv/statistics/Cordorcet_convert data formats.csv
#
#                                     BoostedBordaFuse  \
# 0  csv/statistics/BoostedBordaFuse_download free ...
# 1  csv/statistics/BoostedBordaFuse_download web v...
# 2  csv/statistics/BoostedBordaFuse_check valid em...
# 3       csv/statistics/BoostedBordaFuse_send sms.csv
# 4  csv/statistics/BoostedBordaFuse_extract barcod...
# 5  csv/statistics/BoostedBordaFuse_convert audio ...
# 6  csv/statistics/BoostedBordaFuse_quick sort alg...
# 7  csv/statistics/BoostedBordaFuse_user authentic...
# 8  csv/statistics/BoostedBordaFuse_filter adult c...
# 9  csv/statistics/BoostedBordaFuse_convert data f...
#
#                        WeightedFirstRankingAgregator
# 0  csv/statistics/WeightedFirstRankingAgregator_d...
# 1  csv/statistics/WeightedFirstRankingAgregator_d...
# 2  csv/statistics/WeightedFirstRankingAgregator_c...
# 3  csv/statistics/WeightedFirstRankingAgregator_s...
# 4  csv/statistics/WeightedFirstRankingAgregator_e...
# 5  csv/statistics/WeightedFirstRankingAgregator_c...
# 6  csv/statistics/WeightedFirstRankingAgregator_q...
# 7  csv/statistics/WeightedFirstRankingAgregator_u...
# 8  csv/statistics/WeightedFirstRankingAgregator_f...
# 9  csv/statistics/WeightedFirstRankingAgregator_c...

# %%
searchers = list(df).copy()
del searchers[0]

for query in range(df['query'].size):
    for searcher in range(len(searchers)):
        mt = pd.read_csv('../'+df.iloc[query][searcher+1])
        df.iloc[query][searcher+1] = mt

# %%
#df = pd.DataFrame([list(s1), list(s2)],  columns =  ["A", "B", "C"])

max_k = 21
resultall = []
result_precision = []
result_hits = []
result_recall = []


for k in range(1,max_k):
    #print(k)
    searchersrow = []
    row_precision = []
    row_hits = []
    row_recall = []
    for searcher in range(len(searchers)):
        #print(searchers[searcher])
        sum_hits = 0
        sum_precision = 0
        sum_recall = 0
        sum_fmeasure = 0
        for query in range(df['query'].size):         
            sxq = df.iloc[query][searcher+1]
            sxq = sxq.set_index('k')
            sum_hits += sxq.loc[k]['hits']
            sum_precision += sxq.loc[k]['precision']
            sum_recall += sxq.loc[k]['recall']
            sum_fmeasure += sxq.loc[k]['fmeasure']
        prom_hits = sum_hits/max_k
        prom_precision = sum_precision/max_k
        prom_recall = sum_recall/max_k
        prom_fmeasure = sum_fmeasure/max_k
        #print(prom_hits)
        #print(prom_precision)
        #print(prom_recall)
        #print(prom_fmeasure)
        searcherprom = pd.DataFrame([[prom_hits,prom_precision,prom_recall,prom_fmeasure]],  columns =  ["hits", "precision", "recall", "fmeasure"])
        searchersrow.append(searcherprom)
        row_precision.append(prom_precision)
        row_hits.append(prom_hits)
        row_recall.append(prom_recall)
    #print(searchersrow)
    resultall.append([k]+searchersrow)
    result_precision.append([k]+row_precision)
    result_hits.append([k]+row_hits)
    result_recall.append([k]+row_recall)

columnsk = ['k'] + searchers
dataframek = pd.DataFrame(resultall, columns =  ['k'] + searchers)
dataframek = dataframek.set_index('k')
dataframek.head(3)

dataframe_hits = pd.DataFrame(result_hits, columns =  ['k'] + searchers)
dataframe_hits.head(3)
dataframe_recall = pd.DataFrame(result_recall, columns =  ['k'] + searchers)
dataframe_recall.head(3)
dataframe_precision = pd.DataFrame(result_precision, columns =  ['k'] + searchers)
dataframe_precision.head(20)
# Out:
#      k    lucene  bing.com_stanford_CRF  google.com_stanford_CRF  \
# 0    1  0.285714               0.047619                 0.047619
# 1    2  0.357143               0.047619                 0.023810
# 2    3  0.349206               0.031746                 0.015873
# 3    4  0.357143               0.023810                 0.023810
# 4    5  0.361905               0.019048                 0.019048
# 5    6  0.349206               0.015873                 0.015873
# 6    7  0.340136               0.013605                 0.013605
# 7    8  0.333333               0.011905                 0.011905
# 8    9  0.312169               0.010582                 0.010582
# 9   10  0.309524               0.009524                 0.009524
# 10  11  0.311688               0.008658                 0.008658
# 11  12  0.309524               0.007937                 0.007937
# 12  13  0.307692               0.007326                 0.007326
# 13  14  0.302721               0.006803                 0.006803
# 14  15  0.298413               0.006349                 0.006349
# 15  16  0.294643               0.005952                 0.005952
# 16  17  0.291317               0.005602                 0.005602
# 17  18  0.291005               0.005291                 0.005291
# 18  19  0.290727               0.005013                 0.005013
# 19  20  0.290476               0.004762                 0.004762
#
#     bing.com_str_match  google.com_str_match  bing.com_hyp_match  \
# 0             0.095238              0.142857            0.095238
# 1             0.047619              0.119048            0.095238
# 2             0.063492              0.111111            0.079365
# 3             0.083333              0.083333            0.059524
# 4             0.076190              0.076190            0.057143
# 5             0.063492              0.071429            0.047619
# 6             0.061224              0.061224            0.047619
# 7             0.059524              0.053571            0.053571
# 8             0.052910              0.052910            0.063492
# 9             0.047619              0.052381            0.061905
# 10            0.043290              0.047619            0.056277
# 11            0.039683              0.043651            0.055556
# 12            0.036630              0.047619            0.051282
# 13            0.034014              0.047619            0.051020
# 14            0.031746              0.044444            0.047619
# 15            0.029762              0.044643            0.047619
# 16            0.028011              0.050420            0.050420
# 17            0.026455              0.055556            0.047619
# 18            0.025063              0.060150            0.047619
# 19            0.023810              0.057143            0.050000
#
#     google.com_hyp_match  npmjs.com_optimal  npmsearch.com        M1  \
# 0               0.047619           0.285714       0.095238  0.142857
# 1               0.047619           0.285714       0.119048  0.166667
# 2               0.079365           0.253968       0.095238  0.174603
# 3               0.059524           0.226190       0.095238  0.214286
# 4               0.057143           0.219048       0.085714  0.209524
# 5               0.047619           0.222222       0.087302  0.222222
# 6               0.061224           0.210884       0.088435  0.231293
# 7               0.059524           0.208333       0.089286  0.232143
# 8               0.058201           0.206349       0.089947  0.227513
# 9               0.052381           0.200000       0.085714  0.228571
# 10              0.056277           0.199134       0.082251  0.238095
# 11              0.063492           0.198413       0.079365  0.238095
# 12              0.062271           0.194139       0.076923  0.238095
# 13              0.068027           0.193878       0.074830  0.241497
# 14              0.063492           0.193651       0.076190  0.244444
# 15              0.059524           0.190476       0.077381  0.241071
# 16              0.056022           0.190476       0.075630  0.232493
# 17              0.052910           0.190476       0.074074  0.232804
# 18              0.052632           0.190476       0.075188  0.233083
# 19              0.050000           0.185714       0.076190  0.233333
#
#           M2        M3        M4  BordaFuse  Cordorcet  BoostedBordaFuse  \
# 0   0.142857  0.142857  0.190476   0.190476   0.285714          0.190476
# 1   0.190476  0.119048  0.214286   0.309524   0.261905          0.309524
# 2   0.206349  0.142857  0.206349   0.317460   0.206349          0.317460
# 3   0.202381  0.142857  0.202381   0.309524   0.226190          0.309524
# 4   0.200000  0.161905  0.190476   0.323810   0.238095          0.323810
# 5   0.214286  0.174603  0.182540   0.333333   0.238095          0.341270
# 6   0.217687  0.183673  0.170068   0.312925   0.217687          0.319728
# 7   0.226190  0.196429  0.166667   0.309524   0.202381          0.309524
# 8   0.227513  0.195767  0.169312   0.306878   0.216931          0.306878
# 9   0.223810  0.200000  0.157143   0.304762   0.209524          0.304762
# 10  0.233766  0.212121  0.151515   0.298701   0.199134          0.303030
# 11  0.230159  0.214286  0.142857   0.297619   0.190476          0.305556
# 12  0.230769  0.223443  0.146520   0.289377   0.190476          0.289377
# 13  0.234694  0.231293  0.149660   0.282313   0.180272          0.289116
# 14  0.238095  0.238095  0.146032   0.279365   0.184127          0.282540
# 15  0.235119  0.238095  0.142857   0.279762   0.187500          0.279762
# 16  0.232493  0.240896  0.137255   0.274510   0.187675          0.274510
# 17  0.235450  0.238095  0.132275   0.277778   0.182540          0.277778
# 18  0.238095  0.240602  0.130326   0.275689   0.182957          0.273183
# 19  0.238095  0.240476  0.130952   0.276190   0.183333          0.273810
#
#     WeightedFirstRankingAgregator
# 0                        0.190476
# 1                        0.285714
# 2                        0.317460
# 3                        0.309524
# 4                        0.314286
# 5                        0.317460
# 6                        0.319728
# 7                        0.321429
# 8                        0.312169
# 9                        0.304762
# 10                       0.311688
# 11                       0.305556
# 12                       0.304029
# 13                       0.302721
# 14                       0.298413
# 15                       0.297619
# 16                       0.296919
# 17                       0.293651
# 18                       0.290727
# 19                       0.288095

# %%
import matplotlib.pyplot as pl

def plplotk(pl,searcher,dataf):
        pl.plot(dataf['k'].tolist(), dataf[searcher].tolist(), label=searcher)

for searcher in range(len(searchers)):
    plplotk(pl,searchers[searcher],dataframe_hits)
    
pl.xlabel('k')
pl.ylabel('hits')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-hit curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()


for searcher in range(len(searchers)):
    plplotk(pl,searchers[searcher],dataframe_precision)
    
pl.xlabel('k')
pl.ylabel('precision')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-precision curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()


for searcher in range(len(searchers)):
    plplotk(pl,searchers[searcher],dataframe_recall)
    
pl.xlabel('k')
pl.ylabel('recall')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-recall curve: ')
pl.legend(loc='center left', bbox_to_anchor=(1, 0.5))
pl.show()
