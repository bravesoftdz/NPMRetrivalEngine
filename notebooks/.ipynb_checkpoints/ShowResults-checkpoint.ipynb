# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../csv/statistics.csv')
df = df.dropna()
df
# Out:
#                                          query  \
# 0                          download free music
# 1   convert typewritten image to text document
# 2                          download web videos
# 3                    check valid email address
# 4                                     send sms
# 5                   extract barcode from image
# 6                        convert audio to text
# 7                         quick sort algorithm
# 9                          user authentication
# 10                 filter adult content images
# 11                        convert data formats
#
#                         WeightedFirstRankingAgregator  \
# 0   csv/statistics/WeightedFirstRankingAgregator_d...
# 1   csv/statistics/WeightedFirstRankingAgregator_c...
# 2   csv/statistics/WeightedFirstRankingAgregator_d...
# 3   csv/statistics/WeightedFirstRankingAgregator_c...
# 4   csv/statistics/WeightedFirstRankingAgregator_s...
# 5   csv/statistics/WeightedFirstRankingAgregator_e...
# 6   csv/statistics/WeightedFirstRankingAgregator_c...
# 7   csv/statistics/WeightedFirstRankingAgregator_q...
# 9   csv/statistics/WeightedFirstRankingAgregator_u...
# 10  csv/statistics/WeightedFirstRankingAgregator_f...
# 11  csv/statistics/WeightedFirstRankingAgregator_c...
#
#                              WeightedRankingAgregator  \
# 0   csv/statistics/WeightedRankingAgregator_downlo...
# 1   csv/statistics/WeightedRankingAgregator_conver...
# 2   csv/statistics/WeightedRankingAgregator_downlo...
# 3   csv/statistics/WeightedRankingAgregator_check ...
# 4   csv/statistics/WeightedRankingAgregator_send s...
# 5   csv/statistics/WeightedRankingAgregator_extrac...
# 6   csv/statistics/WeightedRankingAgregator_conver...
# 7   csv/statistics/WeightedRankingAgregator_quick ...
# 9   csv/statistics/WeightedRankingAgregator_user a...
# 10  csv/statistics/WeightedRankingAgregator_filter...
# 11  csv/statistics/WeightedRankingAgregator_conver...
#
#                        WeightedRankingAgregator701010  \
# 0   csv/statistics/WeightedRankingAgregator701010_...
# 1   csv/statistics/WeightedRankingAgregator701010_...
# 2   csv/statistics/WeightedRankingAgregator701010_...
# 3   csv/statistics/WeightedRankingAgregator701010_...
# 4   csv/statistics/WeightedRankingAgregator701010_...
# 5   csv/statistics/WeightedRankingAgregator701010_...
# 6   csv/statistics/WeightedRankingAgregator701010_...
# 7   csv/statistics/WeightedRankingAgregator701010_...
# 9   csv/statistics/WeightedRankingAgregator701010_...
# 10  csv/statistics/WeightedRankingAgregator701010_...
# 11  csv/statistics/WeightedRankingAgregator701010_...
#
#                                                lucene  \
# 0       csv/statistics/lucene_download free music.csv
# 1   csv/statistics/lucene_convert typewritten imag...
# 2       csv/statistics/lucene_download web videos.csv
# 3   csv/statistics/lucene_check valid email addres...
# 4                  csv/statistics/lucene_send sms.csv
# 5   csv/statistics/lucene_extract barcode from ima...
# 6     csv/statistics/lucene_convert audio to text.csv
# 7      csv/statistics/lucene_quick sort algorithm.csv
# 9       csv/statistics/lucene_user authentication.csv
# 10  csv/statistics/lucene_filter adult content ima...
# 11     csv/statistics/lucene_convert data formats.csv
#
#                                              bing.com  \
# 0     csv/statistics/bing.com_download free music.csv
# 1   csv/statistics/bing.com_convert typewritten im...
# 2     csv/statistics/bing.com_download web videos.csv
# 3   csv/statistics/bing.com_check valid email addr...
# 4                csv/statistics/bing.com_send sms.csv
# 5   csv/statistics/bing.com_extract barcode from i...
# 6   csv/statistics/bing.com_convert audio to text.csv
# 7    csv/statistics/bing.com_quick sort algorithm.csv
# 9     csv/statistics/bing.com_user authentication.csv
# 10  csv/statistics/bing.com_filter adult content i...
# 11   csv/statistics/bing.com_convert data formats.csv
#
#                                            google.com  \
# 0   csv/statistics/google.com_download free music.csv
# 1   csv/statistics/google.com_convert typewritten ...
# 2   csv/statistics/google.com_download web videos.csv
# 3   csv/statistics/google.com_check valid email ad...
# 4              csv/statistics/google.com_send sms.csv
# 5   csv/statistics/google.com_extract barcode from...
# 6   csv/statistics/google.com_convert audio to tex...
# 7   csv/statistics/google.com_quick sort algorithm...
# 9   csv/statistics/google.com_user authentication.csv
# 10  csv/statistics/google.com_filter adult content...
# 11  csv/statistics/google.com_convert data formats...
#
#                                    npmjs.comoptimal20  \
# 0   csv/statistics/npmjs.comoptimal20_download fre...
# 1   csv/statistics/npmjs.comoptimal20_convert type...
# 2   csv/statistics/npmjs.comoptimal20_download web...
# 3   csv/statistics/npmjs.comoptimal20_check valid ...
# 4      csv/statistics/npmjs.comoptimal20_send sms.csv
# 5   csv/statistics/npmjs.comoptimal20_extract barc...
# 6   csv/statistics/npmjs.comoptimal20_convert audi...
# 7   csv/statistics/npmjs.comoptimal20_quick sort a...
# 9   csv/statistics/npmjs.comoptimal20_user authent...
# 10  csv/statistics/npmjs.comoptimal20_filter adult...
# 11  csv/statistics/npmjs.comoptimal20_convert data...
#
#                                         npmsearch.com
# 0   csv/statistics/npmsearch.com_download free mus...
# 1   csv/statistics/npmsearch.com_convert typewritt...
# 2   csv/statistics/npmsearch.com_download web vide...
# 3   csv/statistics/npmsearch.com_check valid email...
# 4           csv/statistics/npmsearch.com_send sms.csv
# 5   csv/statistics/npmsearch.com_extract barcode f...
# 6   csv/statistics/npmsearch.com_convert audio to ...
# 7   csv/statistics/npmsearch.com_quick sort algori...
# 9   csv/statistics/npmsearch.com_user authenticati...
# 10  csv/statistics/npmsearch.com_filter adult cont...
# 11  csv/statistics/npmsearch.com_convert data form...

# %%
searchers = list(df).copy()
del searchers[0]

for query in range(df['query'].size):
    for searcher in range(len(searchers)):
        mt = pd.read_csv('../'+df.iloc[query][searcher+1])
        df.iloc[query][searcher+1] = mt
# Out:
# csv/statistics/WeightedFirstRankingAgregator_download free music.csv
# csv/statistics/WeightedRankingAgregator_download free music.csv
# csv/statistics/WeightedRankingAgregator701010_download free music.csv
# csv/statistics/lucene_download free music.csv
# csv/statistics/bing.com_download free music.csv
# csv/statistics/google.com_download free music.csv
# csv/statistics/npmjs.comoptimal20_download free music.csv
# csv/statistics/npmsearch.com_download free music.csv
# csv/statistics/WeightedFirstRankingAgregator_convert typewritten image to text document.csv
# csv/statistics/WeightedRankingAgregator_convert typewritten image to text document.csv
# csv/statistics/WeightedRankingAgregator701010_convert typewritten image to text document.csv
# csv/statistics/lucene_convert typewritten image to text document.csv
# csv/statistics/bing.com_convert typewritten image to text document.csv
# csv/statistics/google.com_convert typewritten image to text document.csv
# csv/statistics/npmjs.comoptimal20_convert typewritten image to text document.csv
# csv/statistics/npmsearch.com_convert typewritten image to text document.csv
# csv/statistics/WeightedFirstRankingAgregator_download web videos.csv
# csv/statistics/WeightedRankingAgregator_download web videos.csv
# csv/statistics/WeightedRankingAgregator701010_download web videos.csv
# csv/statistics/lucene_download web videos.csv
# csv/statistics/bing.com_download web videos.csv
# csv/statistics/google.com_download web videos.csv
# csv/statistics/npmjs.comoptimal20_download web videos.csv
# csv/statistics/npmsearch.com_download web videos.csv
# csv/statistics/WeightedFirstRankingAgregator_check valid email address.csv
# csv/statistics/WeightedRankingAgregator_check valid email address.csv
# csv/statistics/WeightedRankingAgregator701010_check valid email address.csv
# csv/statistics/lucene_check valid email address.csv
# csv/statistics/bing.com_check valid email address.csv
# csv/statistics/google.com_check valid email address.csv
# csv/statistics/npmjs.comoptimal20_check valid email address.csv
# csv/statistics/npmsearch.com_check valid email address.csv
# csv/statistics/WeightedFirstRankingAgregator_send sms.csv
# csv/statistics/WeightedRankingAgregator_send sms.csv
# csv/statistics/WeightedRankingAgregator701010_send sms.csv
# csv/statistics/lucene_send sms.csv
# csv/statistics/bing.com_send sms.csv
# csv/statistics/google.com_send sms.csv
# csv/statistics/npmjs.comoptimal20_send sms.csv
# csv/statistics/npmsearch.com_send sms.csv
# csv/statistics/WeightedFirstRankingAgregator_extract barcode from image.csv
# csv/statistics/WeightedRankingAgregator_extract barcode from image.csv
# csv/statistics/WeightedRankingAgregator701010_extract barcode from image.csv
# csv/statistics/lucene_extract barcode from image.csv
# csv/statistics/bing.com_extract barcode from image.csv
# csv/statistics/google.com_extract barcode from image.csv
# csv/statistics/npmjs.comoptimal20_extract barcode from image.csv
# csv/statistics/npmsearch.com_extract barcode from image.csv
# csv/statistics/WeightedFirstRankingAgregator_convert audio to text.csv
# csv/statistics/WeightedRankingAgregator_convert audio to text.csv
# csv/statistics/WeightedRankingAgregator701010_convert audio to text.csv
# csv/statistics/lucene_convert audio to text.csv
# csv/statistics/bing.com_convert audio to text.csv
# csv/statistics/google.com_convert audio to text.csv
# csv/statistics/npmjs.comoptimal20_convert audio to text.csv
# csv/statistics/npmsearch.com_convert audio to text.csv
# csv/statistics/WeightedFirstRankingAgregator_quick sort algorithm.csv
# csv/statistics/WeightedRankingAgregator_quick sort algorithm.csv
# csv/statistics/WeightedRankingAgregator701010_quick sort algorithm.csv
# csv/statistics/lucene_quick sort algorithm.csv
# csv/statistics/bing.com_quick sort algorithm.csv
# csv/statistics/google.com_quick sort algorithm.csv
# csv/statistics/npmjs.comoptimal20_quick sort algorithm.csv
# csv/statistics/npmsearch.com_quick sort algorithm.csv
# csv/statistics/WeightedFirstRankingAgregator_user authentication.csv
# csv/statistics/WeightedRankingAgregator_user authentication.csv
# csv/statistics/WeightedRankingAgregator701010_user authentication.csv
# csv/statistics/lucene_user authentication.csv
# csv/statistics/bing.com_user authentication.csv
# csv/statistics/google.com_user authentication.csv
# csv/statistics/npmjs.comoptimal20_user authentication.csv
# csv/statistics/npmsearch.com_user authentication.csv
# csv/statistics/WeightedFirstRankingAgregator_filter adult content images.csv
# csv/statistics/WeightedRankingAgregator_filter adult content images.csv
# csv/statistics/WeightedRankingAgregator701010_filter adult content images.csv
# csv/statistics/lucene_filter adult content images.csv
# csv/statistics/bing.com_filter adult content images.csv
# csv/statistics/google.com_filter adult content images.csv
# csv/statistics/npmjs.comoptimal20_filter adult content images.csv
# csv/statistics/npmsearch.com_filter adult content images.csv
# csv/statistics/WeightedFirstRankingAgregator_convert data formats.csv
# csv/statistics/WeightedRankingAgregator_convert data formats.csv
# csv/statistics/WeightedRankingAgregator701010_convert data formats.csv
# csv/statistics/lucene_convert data formats.csv
# csv/statistics/bing.com_convert data formats.csv
# csv/statistics/google.com_convert data formats.csv
# csv/statistics/npmjs.comoptimal20_convert data formats.csv
# csv/statistics/npmsearch.com_convert data formats.csv

# %%
df
# Out:
#                                          query  \
# 0                          download free music
# 1   convert typewritten image to text document
# 2                          download web videos
# 3                    check valid email address
# 4                                     send sms
# 5                   extract barcode from image
# 6                        convert audio to text
# 7                         quick sort algorithm
# 9                          user authentication
# 10                 filter adult content images
# 11                        convert data formats
#
#                         WeightedFirstRankingAgregator  \
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision    recall  fmeasure
# 0 ...
# 2        k  hits  precision    recall  fmeasure
# 0 ...
# 3        k  hits  precision    recall  fmeasure
# 0 ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                              WeightedRankingAgregator  \
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision    recall  fmeasure
# 0 ...
# 2        k  hits  precision    recall  fmeasure
# 0 ...
# 3        k  hits  precision    recall  fmeasure
# 0 ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                        WeightedRankingAgregator701010  \
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision    recall  fmeasure
# 0 ...
# 2        k  hits  precision    recall  fmeasure
# 0 ...
# 3        k  hits  precision    recall  fmeasure
# 0 ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                                                lucene  \
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision    recall  fmeasure
# 0 ...
# 2        k  hits  precision    recall  fmeasure
# 0 ...
# 3        k  hits  precision    recall  fmeasure
# 0 ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                                              bing.com  \
# 0        k  hits  precision  recall  fmeasure
# 0   ...
# 1        k  hits  precision  recall  fmeasure
# 0   ...
# 2        k  hits  precision    recall  fmeasure
# 0 ...
# 3        k  hits  precision  recall  fmeasure
# 0   ...
# 4        k  hits  precision  recall  fmeasure
# 0   ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                                            google.com  \
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision    recall  fmeasure
# 0 ...
# 2        k  hits  precision  recall  fmeasure
# 0   ...
# 3        k  hits  precision    recall  fmeasure
# 0 ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                                    npmjs.comoptimal20  \
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision  recall  fmeasure
# 0   ...
# 2        k  hits  precision    recall  fmeasure
# 0 ...
# 3        k  hits  precision    recall  fmeasure
# 0 ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision    recall  fmeasure
# 0 ...
#
#                                         npmsearch.com
# 0        k  hits  precision    recall  fmeasure
# 0 ...
# 1        k  hits  precision  recall  fmeasure
# 0   ...
# 2        k  hits  precision  recall  fmeasure
# 0   ...
# 3        k  hits  precision  recall  fmeasure
# 0   ...
# 4        k  hits  precision    recall  fmeasure
# 0 ...
# 5        k  hits  precision  recall  fmeasure
# 0   ...
# 6        k  hits  precision  recall  fmeasure
# 0   ...
# 7        k  hits  precision    recall  fmeasure
# 0 ...
# 9        k  hits  precision    recall  fmeasure
# 0 ...
# 10       k  hits  precision  recall  fmeasure
# 0   ...
# 11       k  hits  precision  recall  fmeasure
# 0   ...

# %%
for query in range(df['query'].size):
    for searcher in range(len(searchers)):
        toplot = df.iloc[query][searcher+1]
        break

toplot
#lot_k(df.iloc[query][searcher+1]['k'].tolist(),df.iloc[query][searcher+1]['hits'].tolist())
# Out:
#      k  hits  precision    recall  fmeasure
# 0    1   1.0   0.500000  0.029412  0.055556
# 1    2   2.0   0.666667  0.058824  0.108108
# 2    3   3.0   0.750000  0.088235  0.157895
# 3    4   4.0   0.800000  0.117647  0.205128
# 4    5   5.0   0.833333  0.147059  0.250000
# 5    6   6.0   0.857143  0.176471  0.292683
# 6    7   7.0   0.875000  0.205882  0.333333
# 7    8   7.0   0.777778  0.205882  0.325581
# 8    9   7.0   0.700000  0.205882  0.318182
# 9   10   8.0   0.727273  0.235294  0.355556
# 10  11   9.0   0.750000  0.264706  0.391304
# 11  12  10.0   0.769231  0.294118  0.425532
# 12  13  11.0   0.785714  0.323529  0.458333
# 13  14  12.0   0.800000  0.352941  0.489796
# 14  15  12.0   0.750000  0.352941  0.480000
# 15  16  13.0   0.764706  0.382353  0.509804
# 16  17  14.0   0.777778  0.411765  0.538462
# 17  18  14.0   0.736842  0.411765  0.528302
# 18  19  15.0   0.750000  0.441176  0.555556

# %%
from sklearn.metrics import auc
import matplotlib.pyplot as pl
from matplotlib.ticker import MaxNLocator

def plot_auc(recall, precision):

    area = auc(recall, precision)
    print("Area Under Curve: %0.2f" % area)

    pl.clf()
    pl.plot(recall, precision, label='Precision-Recall curve')
    pl.xlabel('Recall')
    pl.ylabel('Precision')
    pl.ylim([0.0, 1.05])
    pl.xlim([0.0, 1.0])
    pl.title('Precision-Recall example: AUC=%0.2f' % area)
    pl.legend(loc="lower left")
    pl.show()
    
def plot_k(k, metric):

    #area = auc(recall, precision)
    #print("Area Under Curve: %0.2f" % area)

    #pl.clf()
    pl.plot(k, metric, label='k-metric curve')
    pl.xlabel('k')
    pl.ylabel('metric')
    
    #pl.ylim([0.0, 21.05])
   # pl.xlim([1, 20])
    pl.title('k-hit curve: ')
    pl.legend(loc="lower left")
    pl.show()

# %%
plot_k(toplot['k'].tolist(),toplot['fmeasure'].tolist())

# %%
df.to_csv('C:/Users/Usuarioç/Desktop/df.csv')

# %%
#df = pd.DataFrame([list(s1), list(s2)],  columns =  ["A", "B", "C"])

max_k = 20
resultall = []
result_precision = []
result_hits = []
result_recall = []


for k in range(1,max_k):
    #print(k)
    searchersrow = []
    row_precision = []
    row_hits = []
    row_recall = []
    for searcher in range(len(searchers)):
        #print(searchers[searcher])
        sum_hits = 0
        sum_precision = 0
        sum_recall = 0
        sum_fmeasure = 0
        for query in range(df['query'].size):         
            sxq = df.iloc[query][searcher+1]
            sxq = sxq.set_index('k')
            sum_hits += sxq.loc[k]['hits']
            sum_precision += sxq.loc[k]['precision']
            sum_recall += sxq.loc[k]['recall']
            sum_fmeasure += sxq.loc[k]['fmeasure']
        prom_hits = sum_hits/max_k
        prom_precision = sum_precision/max_k
        prom_recall = sum_recall/max_k
        prom_fmeasure = sum_fmeasure/max_k
        #print(prom_hits)
        #print(prom_precision)
        #print(prom_recall)
        #print(prom_fmeasure)
        searcherprom = pd.DataFrame([[prom_hits,prom_precision,prom_recall,prom_fmeasure]],  columns =  ["hits", "precision", "recall", "fmeasure"])
        searchersrow.append(searcherprom)
        row_precision.append(prom_precision)
        row_hits.append(prom_hits)
        row_recall.append(prom_recall)
    #print(searchersrow)
    resultall.append([k]+searchersrow)
    result_precision.append([k]+row_precision)
    result_hits.append([k]+row_hits)
    result_recall.append([k]+row_recall)

columnsk = ['k'] + searchers
dataframek = pd.DataFrame(resultall, columns =  ['k'] + searchers)
dataframek = dataframek.set_index('k')
dataframek.head(3)

dataframe_precision = pd.DataFrame(result_precision, columns =  ['k'] + searchers)
dataframe_precision.head(3)
dataframe_hits = pd.DataFrame(result_hits, columns =  ['k'] + searchers)
dataframe_hits.head(3)
dataframe_recall = pd.DataFrame(result_recall, columns =  ['k'] + searchers)
dataframe_recall.head(3)
# Out:
#    k  WeightedFirstRankingAgregator  WeightedRankingAgregator  \
# 0  1                       0.048234                  0.006638
# 1  2                       0.064831                  0.006638
# 2  3                       0.076638                  0.007702
#
#    WeightedRankingAgregator701010    lucene  bing.com  google.com  \
# 0                        0.006638  0.047750  0.000000    0.029413
# 1                        0.009579  0.098480  0.002788    0.033672
# 2                        0.010643  0.105077  0.004512    0.033672
#
#    npmjs.comoptimal20  npmsearch.com
# 0            0.018403       0.008611
# 1            0.025561       0.009520
# 2            0.028714       0.010429

# %%
import matplotlib.pyplot as pl

def plplotk(pl,searcher,dataf):
        pl.plot(dataf['k'].tolist(), dataf[searcher].tolist(), label=searcher)

for searcher in range(len(searchers)):
    plplotk(pl,searchers[searcher],dataframe_hits)
    
pl.xlabel('k')
pl.ylabel('hits')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-hit curve: ')
pl.legend(loc="lower left")
pl.show()


for searcher in range(len(searchers)):
    plplotk(pl,searchers[searcher],dataframe_precision)
    
pl.xlabel('k')
pl.ylabel('precision')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-precision curve: ')
pl.legend(loc="lower left")
pl.show()


for searcher in range(len(searchers)):
    plplotk(pl,searchers[searcher],dataframe_recall)
    
pl.xlabel('k')
pl.ylabel('recall')
#pl.ylim([0.0, 21.05])
# pl.xlim([1, 20])
pl.title('k-recall curve: ')
pl.legend(loc="lower left")
pl.show()
